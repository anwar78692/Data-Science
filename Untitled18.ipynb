# %% [markdown]
# # PROJECT: - Naïve Bees: Image Loading and Processing

# %%
# Used to change filepaths
from pathlib import Path

# We set up matplotlib, pandas, and the display function
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display
import pandas as pd

# import numpy 
import numpy as np

# import Image from PIL so we can use it later
from PIL import Image
# generate test_data
test_data = np.random.beta(1, 1, size = (100, 100, 3))
# display the test_data
plt.imshow(test_data)

# %%
# open the image
img = Image.open('C:/Users/HP/Pictures/honey.jpg')

# Get the image size
img_size =img.size

print("The image size is: {}".format(img_size))

# Just having the image as the last line in the cell will display it in the notebook
img
# Out:
# The image size is: (200, 200)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x24EA4FFFEE0>

# %%
# Crop the image to 25, 25, 75, 75
img_cropped = img.crop([25, 25, 75, 75])
display(img_cropped)

# rotate the image by 45 degrees
img_rotated = img.rotate(45, expand = 25)
display(img_rotated)

# flip the image left to right
img_flipped = img.transpose(Image.FLIP_LEFT_RIGHT)
display(img_flipped)
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x24EA7FD9B80>
# <PIL.Image.Image image mode=RGB size=284x284 at 0x24EA7EB5E50>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x24EA7EB59D0>

# %%
# Turn our image object into a NumPy array
img_data = np.array(img)

# get the shape of the resulting array
img_data_shape = img_data.shape

print("Our NumPy array has the shape: {}".format(img_data_shape))

# plot the data with `imshow` 

plt.imshow(img_data)
plt.show()

# plot the red channel
plt.imshow(img_data[:, :, 0], cmap=plt.cm.Reds_r)
plt.show()

# plot the green channel
plt.imshow(img_data[:, :, 1], cmap=plt.cm.Greens_r)
plt.show()

# plot the blue channel
plt.imshow(img_data[:, :, 2], cmap=plt.cm.Blues_r)
plt.show()
# Out:
# Our NumPy array has the shape: (200, 200, 3)

# %%
def plot_kde(channel, color):
    """ Plots a kernel density estimate for the given data.
        
        `channel` must be a 2d array
        `color` must be a color string, e.g. 'r', 'g', or 'b'
    """
    data = channel.flatten()
    return pd.Series(data).plot.density(c=color)

# create the list of channels
channels = ['r', 'g', 'b']
    
def plot_rgb(image_data):
    # use enumerate to loop over colors and indexes
    for ix, color in enumerate(channels):
        plot_kde(img_data[:, :, ix], color)

    plt.show()
    
plot_rgb(img_data)

# %%
# load bee_12.jpg as honey
honey = Image.open('C:/Users/HP/Pictures/download.png')
# display the honey bee image
display(honey)

# NumPy array of the honey bee image data
honey_data = np.array(honey)
# plot the rgb densities for the honey bee image
plot_rgb(honey_data)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100 at 0x24EA910FD30>

# %%
# load bee_3.jpg as bumble
bumble = Image.open('C:/Users/HP/Pictures/download (1).png')
# display the bumble bee image
display(bumble)

# NumPy array of the bumble bee image data
bumble_data = np.array(bumble)
# plot the rgb densities for the bumble bee image
plot_rgb(bumble_data)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100 at 0x24EA7FD9100>

# %%
# convert honey to grayscale
honey_bw = honey.convert("L")
display(honey_bw)

# convert the image to a NumPy array
honey_bw_arr = np.array(honey_bw)

# get the shape of the resulting array
honey_bw_arr_shape = honey_bw_arr.shape
print("Our NumPy array has the shape: {}".format(honey_bw_arr_shape))

# plot the array using matplotlib
plt.imshow(honey_bw_arr, cmap=plt.cm.gray)
plt.show()

# plot the kde of the new black and white array
plot_kde(honey_bw_arr, 'k')
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x24EAA0381F0>
# Our NumPy array has the shape: (100, 100)
# <AxesSubplot:ylabel='Density'>

# %%
# flip the image left-right with transpose
honey_bw_flip = honey_bw.transpose(Image.FLIP_LEFT_RIGHT)

# show the flipped image
display(honey_bw_flip)

# save the flipped image
honey_bw_flip.save("C:/Users/HP/Pictures/download (1).png")

# create higher contrast by reducing range
honey_hc_arr = np.maximum(honey_bw_arr, 100)

# show the higher contrast version
plt.imshow(honey_hc_arr, cmap=plt.cm.gray)

# convert the NumPy array of high contrast to an Image
honey_bw_hc = Image.fromarray(honey_hc_arr)

# save the high contrast version
honey_bw_hc.save("C:/Users/HP/Pictures/download (1).png")
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x24EAA1B5F10>

# %%
image_paths = ['C:/Users/HP/Pictures/honey.jpg', 'C:/Users/HP/Pictures/download (1).png', 'C:/Users/HP/Pictures/download.png', 'C:/Users/HP/Pictures/download.png']

def process_image(path):
    img = Image.open(path)

    # create paths to save files to
    bw_path = "C:/Users/HP/Pictures/download (1).png".format(path.stem)
    rcz_path = "C:/Users/HP/Pictures/download (1).png".format(path.stem)

    print("Creating grayscale version of {} and saving to {}.".format(path, bw_path))
    bw = img.convert("L")

    print("Creating rotated, cropped, and zoomed version of {} and saving to {}.".format(path, rcz_path))
    rcz = bw.rotate(45).crop([25, 25, 75, 75])
    rcz.save(rcz_path)

# for loop over image paths
for img_path in image_paths:
    process_image(Path(img_path))
# Out:
# Creating grayscale version of C:\Users\HP\Pictures\honey.jpg and saving to C:/Users/HP/Pictures/download (1).png.
# Creating rotated, cropped, and zoomed version of C:\Users\HP\Pictures\honey.jpg and saving to C:/Users/HP/Pictures/download (1).png.
# Creating grayscale version of C:\Users\HP\Pictures\download (1).png and saving to C:/Users/HP/Pictures/download (1).png.
# Creating rotated, cropped, and zoomed version of C:\Users\HP\Pictures\download (1).png and saving to C:/Users/HP/Pictures/download (1).png.
# Creating grayscale version of C:\Users\HP\Pictures\download.png and saving to C:/Users/HP/Pictures/download (1).png.
# Creating rotated, cropped, and zoomed version of C:\Users\HP\Pictures\download.png and saving to C:/Users/HP/Pictures/download (1).png.
# Creating grayscale version of C:\Users\HP\Pictures\download.png and saving to C:/Users/HP/Pictures/download (1).png.
# Creating rotated, cropped, and zoomed version of C:\Users\HP\Pictures\download.png and saving to C:/Users/HP/Pictures/download (1).png.
